# %%
import sys
sys.path.append("embed")

from embeder import Embedder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       1 import sys
#       2 sys.path.append("embed")
#       3
# ----> 4 from embeder import Embedder
#
# ModuleNotFoundError: No module named 'embeder'

# %%
embed = Embedder()

q1 = "Can I still join the course after the start date?"
q2 = "How to install Docker on Windows?"
d  = "You don't need to register. You're accepted. You can also just start learning and submitting homework without registering."

v1 = embed.encode(q1)
v2 = embed.encode(q2)
dv = embed.encode(d)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from embed.embeder import Embedder
#       2
#       3 embed = Embedder()
#       4
#
# ModuleNotFoundError: No module named 'embed'
